# %% [markdown]
# # Data Analytics III
# 1. Implement Simple Naïve Bayes classification algorithm using Python/R on iris.csv dataset.
# 2. Compute Confusion matrix to find TP, FP, TN, FN, Accuracy, Error rate, Precision, Recall
# on the given dataset.

# %% [markdown]
# ### Naive Bayes is a probabilistic classification algorithm based on Bayes' theorem.
# It assumes that the presence of a particular feature in a class is independent of the presence of other features

# %% [markdown]
#  Naive Bayes is a classification algorithm that calculates the probability of a class given the features and selects the most probable class.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ● Naïve Bayes Classifier can be used for Classification of categorical data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np 
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
X=df.iloc[:,0:4]
Y=df.iloc[:,-1]

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
Y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %% [markdown]
# ## test and train split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,x_test,Y_train,y_test=train_test_split(X,Y,test_size=0.3,shuffle=True)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gb=GaussianNB()

# %%
gb
# Out:
# GaussianNB()

# %%
gb.fit(X_train,Y_train)
# Out:
# GaussianNB()

# %%
y_pred=gb.predict(x_test)

# %%
y_pred
# Out:
# array(['virginica', 'virginica', 'setosa', 'setosa', 'versicolor',
#        'virginica', 'setosa', 'versicolor', 'versicolor', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'virginica',
#        'versicolor', 'setosa', 'virginica', 'virginica', 'versicolor',
#        'virginica', 'setosa', 'setosa', 'setosa', 'setosa', 'versicolor',
#        'virginica', 'versicolor', 'setosa', 'versicolor', 'setosa',
#        'setosa', 'virginica', 'virginica', 'virginica', 'versicolor',
#        'versicolor', 'virginica', 'versicolor', 'versicolor', 'virginica',
#        'setosa', 'versicolor', 'setosa'], dtype='<U10')

# %% [markdown]
# ## Sccores

# %%
gb.score(x_test,y_test)
# Out:
# 0.9555555555555556

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay,precision_score, recall_score, f1_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9555555555555556

# %%
print(f"Error rate is {1-accuracy_score(y_test, y_pred)}")
# Out:
# Error rate is 0.0444444444444444

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[19,  0,  0],
#        [ 0, 12,  1],
#        [ 0,  1, 12]], dtype=int64)

# %%
disp=ConfusionMatrixDisplay(confusion_matrix=cm)

# %%
disp.plot()

# %%
def get_confusion_matrix_values(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    return(cm[0][0], cm[0][1], cm[1][0], cm[1][1])

TP, FP, FN, TN = get_confusion_matrix_values(y_test, y_pred)
print("TP: ", TP)
print("FP: ", FP)
print("FN: ", FN)
print("TN: ", TN)
# Out:
# TP:  19
# FP:  0
# FN:  0
# TN:  12

# %%
print("The Accuracy is ", (TP+TN)/(TP+TN+FP+FN))
print("The precision is ", TP/(TP+FP))
print("The recall is ", TP/(TP+FN))
# Out:
# The Accuracy is  1.0
# The precision is  1.0
# The recall is  1.0
